# %%
import pandas as pd
import numpy as np

# %%
dt = pd.read_csv('../data/tweets-CUSTOM.csv')

print(dt.shape)
dt.head()
# Out:
# (764, 7)
#                     id                                               text  \
# 0  1517236891606790144                              Believe in the future
# 1  1517219715520901121  @APompliano Tesla is really a dozen or more st...
# 2  1517218742291382272  @SpaceX Starlink satellites deployed into init...
# 3  1517215736606957573                   And authenticate all real humans
# 4  1517215588376092673               @johnkrausphotos Indeed (heavy sigh)
#
#    author_id                created_at  \
# 0   44196397  2022-04-21T20:20:38.000Z
# 1   44196397  2022-04-21T19:12:23.000Z
# 2   44196397  2022-04-21T19:08:31.000Z
# 3   44196397  2022-04-21T18:56:34.000Z
# 4   44196397  2022-04-21T18:55:59.000Z
#
#                                       public_metrics lang  geo
# 0  {'retweet_count': 16506, 'reply_count': 11144,...   en  NaN
# 1  {'retweet_count': 2541, 'reply_count': 1582, '...   en  NaN
# 2  {'retweet_count': 1710, 'reply_count': 973, 'l...   en  NaN
# 3  {'retweet_count': 19505, 'reply_count': 14106,...   en  NaN
# 4  {'retweet_count': 368, 'reply_count': 608, 'li...   en  NaN

# %%
dt.describe(include='all')
# Out:
#                   id                                               text  \
# count   7.640000e+02                                                764
# unique           NaN                                                426
# top              NaN  RT @ApeborgToken: #APEBORG 🐵🦧🦍\n\n🦍 #LAUNCH ON...
# freq             NaN                                                160
# mean    1.517405e+18                                                NaN
# std     3.338763e+14                                                NaN
# min     1.515060e+18                                                NaN
# 25%     1.517485e+18                                                NaN
# 50%     1.517485e+18                                                NaN
# 75%     1.517485e+18                                                NaN
# max     1.517486e+18                                                NaN
#
#            author_id                created_at  \
# count   7.640000e+02                       764
# unique           NaN                       126
# top              NaN  2022-04-22T12:48:20.000Z
# freq             NaN                        45
# mean    1.100597e+18                       NaN
# std     5.981577e+17                       NaN
# min     5.798502e+06                       NaN
# 25%     9.687039e+17                       NaN
# 50%     1.438596e+18                       NaN
# 75%     1.500058e+18                       NaN
# max     1.517485e+18                       NaN
#
#                                            public_metrics lang  geo
# count                                                 764  764  0.0
# unique                                                223    1  NaN
# top     {'retweet_count': 0, 'reply_count': 0, 'like_c...   en  NaN
# freq                                                  204  764  NaN
# mean                                                  NaN  NaN  NaN
# std                                                   NaN  NaN  NaN
# min                                                   NaN  NaN  NaN
# 25%                                                   NaN  NaN  NaN
# 50%                                                   NaN  NaN  NaN
# 75%                                                   NaN  NaN  NaN
# max                                                   NaN  NaN  NaN

# %%
dt.public_metrics[0]
# Out:
# "{'retweet_count': 16506, 'reply_count': 11144, 'like_count': 207693, 'quote_count': 1356}"

# %%
for i, row in dt.iterrows():
    dt.loc[i, ]

# %%
import json

a = '{'tmp':1}''

print(type(json.dumps(a)))
# Out:
# <class 'str'>
