# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/data1.csv')
df.head()
# Out:
#                     id                                               text  \
# 0  1521085224884518915              Wordle 317 3/6\n\n🟩⬜⬜⬜🟨\n🟩🟩🟩🟩⬜\n🟩🟩🟩🟩🟩
# 1  1521085224855158784                Mon daron : https://t.co/5qFZKQWNc8
# 2  1521085224859611137  Don’t cheat with out asking it’s very disrespe...
# 3  1521085224871997440                                 It's coffee time ☕
# 4  1521085229045366787  @JulieKo49989021 Couple either bank own not de...
#
#              author_id                 created_at lang  geo  retweet_count  \
# 0           1260604118  2022-05-02 11:12:32+00:00   en  NaN              0
# 1  1371148461308051459  2022-05-02 11:12:32+00:00   en  NaN              0
# 2   947441279771668482  2022-05-02 11:12:32+00:00   en  NaN              0
# 3             26672170  2022-05-02 11:12:32+00:00   en  NaN              0
# 4  1459553690843598849  2022-05-02 11:12:33+00:00   en  NaN              0
#
#    reply_count  like_count  quote_count
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800047 entries, 0 to 800046
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             800047 non-null  int64
#  1   text           800047 non-null  object
#  2   author_id      800047 non-null  int64
#  3   created_at     800047 non-null  object
#  4   lang           800047 non-null  object
#  5   geo            0 non-null       float64
#  6   retweet_count  800047 non-null  int64
#  7   reply_count    800047 non-null  int64
#  8   like_count     800047 non-null  int64
#  9   quote_count    800047 non-null  int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 61.0+ MB

# %%
df.describe(include='all')
# Out:
#                   id                                               text  \
# count   8.000470e+05                                             800047
# unique           NaN                                             796328
# top              NaN  TitanX is the next big launchpad @TitanX_Proje...
# freq             NaN                                                 42
# mean    1.520337e+18                                                NaN
# std     4.624079e+14                                                NaN
# min     1.519727e+18                                                NaN
# 25%     1.519967e+18                                                NaN
# 50%     1.520146e+18                                                NaN
# 75%     1.520837e+18                                                NaN
# max     1.521095e+18                                                NaN
#
#            author_id                 created_at    lang  geo  retweet_count  \
# ...
